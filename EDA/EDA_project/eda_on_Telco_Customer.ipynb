# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2595  1265-BCFEO  Female              0     Yes         No      71
# 4860  7321-ZNSLA    Male              0     Yes        Yes      13
# 3084  8631-XVRZL    Male              0      No         No       9
# 2888  7409-KIUTL  Female              1      No        Yes       1
# 593   0215-BQKGS    Male              0      No         No      30
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2595          Yes               Yes             DSL                   No  ...
# 4860           No  No phone service             DSL                  Yes  ...
# 3084          Yes                No              No  No internet service  ...
# 2888          Yes                No     Fiber optic                   No  ...
# 593           Yes                No     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     3186-AJIEK   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns = ['customerID'], axis=1,inplace = True)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df['TotalCharges'] = pd.to_numeric(
    df['TotalCharges'],
    errors='coerce'
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df[df['TotalCharges'].isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %% [markdown]
# here we found only new customer (tenure=0) has total_charges missing

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)*100
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.countplot(x='Churn', data=df)
plt.title('Customer Churn Distribution')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The target variable Churn is moderately imbalanced, with 73.42% customers retained and 26.58% customers leaving the service. Therefore, churned customers represent a minority class but are still large enough for meaningful analysis.

# %% [markdown]
# ### Numerical Analysis

# %% [markdown]
# #### senior citizen,tenure,monthly_charges,total_charges

# %%
###Tenure Analysis
df['tenure'].describe()
# Out:
# count    7032.000000
# mean       32.421786
# std        24.545260
# min         1.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='tenure', bins=30, kde=True)
plt.title('Distribution of Customer Tenure')
plt.xlabel('Tenure (months)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Customer tenure ranges from 1 to 72 months. The distribution shows a high concentration of new customers (1–5 months) and another large concentration of long-term customers (around 70–72 months), suggesting the company has both many recently acquired customers and  base of loyal customers.

# %%
sns.boxplot(
    y=df['tenure']
)

plt.title("Tenure Boxplot")
plt.show()

# %% [markdown]
# no outlier detected

# %%
### monthly charges analysis
df['MonthlyCharges'].describe()
# Out:
# count    7032.000000
# mean       64.798208
# std        30.085974
# min        18.250000
# 25%        35.587500
# 50%        70.350000
# 75%        89.862500
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['MonthlyCharges'], bins=30, kde=True)
plt.title('Monthly Charges Distribution')
plt.xlabel('Monthly Charges')
plt.ylabel('Frequency') 
plt.show()

# %% [markdown]
# Most customers fall into either low-cost or high-cost subscription groups.
# Bi-modal Distribution
# There are relatively fewer customers paying between $30 and $60.

# %%
sns.boxplot(
    df['MonthlyCharges'],
    
)
plt.title('Monthly Charges Distribution')
plt.xlabel('Monthly Charges')
plt.show()

# %%
### Total charges analysis
df['TotalCharges'].describe()
# Out:
# count    7032.000000
# mean     2283.300441
# std      2266.771362
# min        18.800000
# 25%       401.450000
# 50%      1397.475000
# 75%      3794.737500
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['TotalCharges'], bins=30, kde=True)
plt.title('Total Charges Distribution') 
plt.xlabel('Total Charges')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The TotalCharges variable is highly right-skewed.
#  Most customers have low total charges, while a small proportion have very high cumulative charges.
#  The distribution has a long right tail, indicating that only a few customers contribute to the highest total charges.
#  unimodal distribution

# %%
sns.boxplot(
    df['TotalCharges']
)
plt.show()

# %%
numeric_cols = [
    'SeniorCitizen',
    'tenure',
    'MonthlyCharges',
    'TotalCharges'
]

# %%
fig, axes = plt.subplots(
    nrows=2,
    ncols=2,
    figsize=(12,8)
)

axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    sns.histplot(
        data=df,
        x=col,
        kde=True,
        ax=axes[i]
    )
    
    axes[i].set_title(f"Distribution of {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical analysis

# %%
Categorical_cols =['gender',
'Contract',
'InternetService',
'PaymentMethod']
fig,axes =plt.subplots(
    nrows=2,
    ncols=2,
    figsize=(12,8)
)
axes = axes.flatten()

for i, col in enumerate(Categorical_cols):
    sns.countplot(
        data=df,
        x=col,
        ax=axes[i]
    )
    
    axes[i].set_title(f"Count of {col}")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

for i, col in enumerate(Categorical_cols):
    counts = df[col].value_counts()

    axes[i].pie(
        counts,
        labels=counts.index,
        autopct='%1.1f%%',
        startangle=90
    )

    axes[i].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# there are equal male and female customer.
#
# month-to-month contract is higher than onece or twice year contract.
#
# Fiber optic is the most widely used internet service among customers, followed by DSL. Only a small portion of customers do not subscribe to internet services.
#
# Electronic check is the preferred payment method among customers.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# #### contract vs churn

# %%
pd.crosstab(
    df['Contract'],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.722826  11.277174
# Two year        97.151335   2.848665

# %%
sns.countplot(
    data=df,
    x='Contract',
    hue='Churn'
)

plt.xticks(rotation=45)
plt.title("Contract vs Churn")
plt.show()

# %%
sns.heatmap(pd.crosstab(df['Contract'], df['Churn'], normalize='index')*100, annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <Axes: xlabel='Churn', ylabel='Contract'>

# %% [markdown]
# ### Tenure vs Churn

# %%
sns.barplot(
    data=df,
    x='tenure',
    hue='Churn'
)

plt.xticks(rotation=45)
plt.title("Tenure vs Churn")
plt.show()

# %%
sns.boxplot(
    data=df,
    x='Churn',
    y='MonthlyCharges'
)

plt.title("Monthly Charges vs Churn")
plt.show()

# %%
sns.boxplot(
    data=df,
    
    x='TotalCharges',
    hue='Churn'
)

plt.title("Total Charges vs Churn")
plt.show()

# %% [markdown]
# tenure short churn also fast

# %%
sns.scatterplot(
    data=df,
    x='tenure',
    y='TotalCharges'
)
# Out:
# <Axes: xlabel='tenure', ylabel='TotalCharges'>

# %%
categorical_cols = [
    'gender',
    'SeniorCitizen',
    'Partner',
    'Dependents',
    'PhoneService',
    'MultipleLines',
    'InternetService',
    'OnlineSecurity',
    'OnlineBackup',
    'DeviceProtection',
    'TechSupport',
    'StreamingTV',
    'StreamingMovies',
    'Contract',
    'PaperlessBilling',
    'PaymentMethod'
]

fig, axes = plt.subplots(
    nrows=4,
    ncols=4,
    figsize=(20,16)
)

axes = axes.flatten()

for i, col in enumerate(categorical_cols):
    sns.countplot(
        data=df,
        x=col,
        hue='Churn',
        ax=axes[i]
    )

    axes[i].set_title(f"{col} vs Churn")
    axes[i].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# Contract:Customers with a month to month contract leave much more often than customers with one year or two year contracts.
#
# Internet Service:Customers using Fiber Optic internet have a higher churn rate than customers using DSL or those without internet service.
#
# Online Security and Tech Support:Customers without Online Security or Tech Support are more likely to leave than those who have these services.
#
# Payment Method:Customers who pay using Electronic Check leave more often than customers using other payment methods.
#
# Partner and Dependents:customers who have a partner or dependents are less likely to churn than customers who do not.
#
# Gender:There is almost no difference in churn between male and female customers.
#
# Phone Service and Multiple Lines:These features do not show a strong effect on customer churn.

# %% [markdown]
# ## multivariate analysis

# %%
numeric_cols = [
    'SeniorCitizen',
    'tenure',
    'MonthlyCharges',
    'TotalCharges'
]

corr = df[numeric_cols].corr()

plt.figure(figsize=(8,5))

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# from this heatmap it is clear that tenure and total charges are strongly correlated,monthly charges are moderately correlated ,seniorcitizen is barely correlated with any other features.

# %%
sns.pairplot(
    df,
    vars=[
        'tenure',
        'MonthlyCharges',
        'TotalCharges'
    ],
    hue='Churn'
)

plt.show()

# %% [markdown]
# Customers who leave the company usually have low tenure.
#
# Customers who churn often have higher monthly charges than customers who stay.
#
# Customers who churn usually have lower total charges because they leave before spending much over time.
