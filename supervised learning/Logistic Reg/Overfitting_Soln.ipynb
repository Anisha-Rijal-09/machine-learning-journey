# %% [markdown]
# ## Overfitting
#
# <img align="left" src="Overfitting_a.png"     style=" width:400px; padding: 10px; " >
# <img align="left" src="Overfitting_b.png"     style=" width:400px; padding: 10px; " >
# <img align="left" src="Overfitting_c.png"   style=" width:400px; padding: 10px; " >
