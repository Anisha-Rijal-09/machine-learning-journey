# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(z):
    g = 1/(1+np.exp(z))
    return g

# %%
z_input = np.arange(-10,11)
y = sigmoid(z_input)
np.set_printoptions(precision=3)
print('input','sigmoid(z)')
print(np.c_[z_input,y])
# Out:
# input sigmoid(z)
# [[-1.000e+01  1.000e+00]
#  [-9.000e+00  9.999e-01]
#  [-8.000e+00  9.997e-01]
#  [-7.000e+00  9.991e-01]
#  [-6.000e+00  9.975e-01]
#  [-5.000e+00  9.933e-01]
#  [-4.000e+00  9.820e-01]
#  [-3.000e+00  9.526e-01]
#  [-2.000e+00  8.808e-01]
#  [-1.000e+00  7.311e-01]
#  [ 0.000e+00  5.000e-01]
#  [ 1.000e+00  2.689e-01]
#  [ 2.000e+00  1.192e-01]
#  [ 3.000e+00  4.743e-02]
#  [ 4.000e+00  1.799e-02]
#  [ 5.000e+00  6.693e-03]
#  [ 6.000e+00  2.473e-03]
#  [ 7.000e+00  9.111e-04]
#  [ 8.000e+00  3.354e-04]
#  [ 9.000e+00  1.234e-04]
#  [ 1.000e+01  4.540e-05]]
